# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from google.colab import drive
from google.colab import files

# %% [markdown]
# ## Read Dataset

# %%
# Load an CSV file
file_path = 'https://www.dropbox.com/scl/fi/hsh5kfc52hv57pkjq3crp/scholastic_travel.csv?rlkey=lzmscfrwl7wfrlgxdhc469zss&st=0c5kf8b9&dl=1'
data = pd.read_csv(file_path)

data.head()
# Out:
#   ProgramCode  FromGrade  ToGrade GroupState  IsNonAnnual  Days TravelType  \
# 0          HS          4        4         CA            0     1          A
# 1          HC          8        8         AZ            0     7          A
# 2          HD          8        8         FL            0     3          A
# 3          HN          9       12      Other            1     3          B
# 4          HD          6        8         FL            0     6      Other
#
#   DepartureDate ReturnDate DepositDate  ... GroupGradeTypeLow  \
# 0       1/14/11    1/14/11     8/30/10  ...                 K
# 1       1/14/11    1/21/11    11/15/09  ...            Middle
# 2       1/15/11    1/17/11    10/15/10  ...            Middle
# 3       1/15/11    1/17/11      1/7/11  ...         Undefined
# 4       1/16/11    1/21/11     9/30/10  ...            Middle
#
#    GroupGradeTypeHigh        GroupGradeType  MajorProgramCode  \
# 0          Elementary         K->Elementary                 H
# 1              Middle        Middle->Middle                 H
# 2              Middle        Middle->Middle                 H
# 3           Undefined  Undefined->Undefined                 H
# 4              Middle        Middle->Middle                 H
#
#    SingleGradeTripFlag FPPtoSchoolenrollment  FPPtoPAX  NumofNonFPPPAX  \
# 0                    1              0.063646  0.936508               4
# 1                    1              0.025882  0.880000               3
# 2                    1              0.025131  0.888889               3
# 3                    0              0.000000  1.000000               0
# 4                    0              0.112500  0.910112               8
#
#    SchoolSizeIndicator RetainedLabel
# 0                    L      Retained
# 1                    L      Retained
# 2                    L      Retained
# 3             FIXED_NA       Churned
# 4                  M-L       Churned
#
# [5 rows x 55 columns]

# %% [markdown]
# ## Data Exploration and preprocessing

# %%
# There are none with missing values :)
data.columns[data.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
data.shape
# Out:
# (2389, 55)

# %%
data["RetainedLabel"].value_counts()
# Out:
# RetainedLabel
# Retained    1451
# Churned      938
# Name: count, dtype: int64

# %%
mapping = {'Retained': 0, 'Churned': 1}
data['RetainedLabel'] = data['RetainedLabel'].map(mapping)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2389 entries, 0 to 2388
# Data columns (total 55 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ProgramCode                     2389 non-null   object
#  1   FromGrade                       2389 non-null   int64
#  2   ToGrade                         2389 non-null   int64
#  3   GroupState                      2389 non-null   object
#  4   IsNonAnnual                     2389 non-null   int64
#  5   Days                            2389 non-null   int64
#  6   TravelType                      2389 non-null   object
#  7   DepartureDate                   2389 non-null   object
#  8   ReturnDate                      2389 non-null   object
#  9   DepositDate                     2389 non-null   object
#  10  SpecialPay                      2389 non-null   object
#  11  Tuition                         2389 non-null   int64
#  12  FRPActive                       2389 non-null   int64
#  13  FRPCancelled                    2389 non-null   int64
#  14  FRPTakeuppercent                2389 non-null   float64
#  15  EarlyRPL                        2389 non-null   object
#  16  LatestRPL                       2389 non-null   object
#  17  CancelledPax                    2389 non-null   int64
#  18  TotalDiscountPax                2389 non-null   int64
#  19  InitialSystemDate               2389 non-null   object
#  20  PovertyCode                     2389 non-null   object
#  21  Region                          2389 non-null   object
#  22  CRMSegment                      2389 non-null   int64
#  23  SchoolType                      2389 non-null   object
#  24  ParentMeetingFlag               2389 non-null   int64
#  25  MDRLowGrade                     2389 non-null   object
#  26  MDRHighGrade                    2389 non-null   int64
#  27  TotalSchoolEnrollment           2389 non-null   int64
#  28  IncomeLevel                     2389 non-null   object
#  29  EZPayTakeUpRate                 2389 non-null   float64
#  30  SchoolSponsor                   2389 non-null   int64
#  31  SPRProductType                  2389 non-null   object
#  32  SPRNewExisting                  2389 non-null   object
#  33  FPP                             2389 non-null   int64
#  34  TotalPax                        2389 non-null   int64
#  35  SPRGroupRevenue                 2389 non-null   int64
#  36  NumberOfMeetingswithParents     2389 non-null   int64
#  37  FirstMeeting                    2389 non-null   object
#  38  LastMeeting                     2389 non-null   object
#  39  DifferenceTraveltoFirstMeeting  2389 non-null   int64
#  40  DifferenceTraveltoLastMeeting   2389 non-null   int64
#  41  SchoolGradeTypeLow              2389 non-null   object
#  42  SchoolGradeTypeHigh             2389 non-null   object
#  43  SchoolGradeType                 2389 non-null   object
#  44  DepartureMonth                  2389 non-null   object
#  45  GroupGradeTypeLow               2389 non-null   object
#  46  GroupGradeTypeHigh              2389 non-null   object
#  47  GroupGradeType                  2389 non-null   object
#  48  MajorProgramCode                2389 non-null   object
#  49  SingleGradeTripFlag             2389 non-null   int64
#  50  FPPtoSchoolenrollment           2389 non-null   float64
#  51  FPPtoPAX                        2389 non-null   float64
#  52  NumofNonFPPPAX                  2389 non-null   int64
#  53  SchoolSizeIndicator             2389 non-null   object
#  54  RetainedLabel                   2389 non-null   int64
# dtypes: float64(4), int64(23), object(28)
# memory usage: 1.0+ MB

# %%
data[[
    "DepartureDate",
    "ReturnDate",
    "DepositDate",
    "EarlyRPL",
    "LatestRPL",
    "InitialSystemDate",
    "FirstMeeting",
    "LastMeeting"]
]
# Out:
#      DepartureDate ReturnDate DepositDate  EarlyRPL LatestRPL  \
# 0          1/14/11    1/14/11     8/30/10   3/29/10   8/12/10
# 1          1/14/11    1/21/11    11/15/09  10/20/09   8/10/10
# 2          1/15/11    1/17/11    10/15/10   4/29/10   8/16/10
# 3          1/15/11    1/17/11      1/7/11    1/1/10    1/1/10
# 4          1/16/11    1/21/11     9/30/10   3/29/10   8/12/10
# ...            ...        ...         ...       ...       ...
# 2384       6/28/11     7/2/11    12/15/10    1/1/10   11/4/10
# 2385       6/29/11     7/3/11    10/15/10   4/26/10    9/7/10
# 2386       6/29/11     7/5/11     1/18/11    1/1/10   12/8/10
# 2387       6/30/11    6/30/11    12/17/10    1/1/10    9/7/10
# 2388       6/30/11     7/5/11    10/29/10    1/1/10   9/15/10
#
#      InitialSystemDate FirstMeeting LastMeeting
# 0              3/26/10      8/12/10     8/12/10
# 1              10/2/09     11/17/09     8/27/10
# 2              1/28/10      9/13/10     9/13/10
# 3             10/19/10       1/1/10      1/1/10
# 4              3/23/10      8/24/10     8/24/10
# ...                ...          ...         ...
# 2384           11/4/10       1/1/10      1/1/10
# 2385           4/27/10       5/6/10     10/7/10
# 2386           12/8/10       1/1/10      1/1/10
# 2387            9/4/10      9/16/10     9/16/10
# 2388           8/28/10      9/30/10     9/30/10
#
# [2389 rows x 8 columns]

# %%
date_cols = [
    "DepartureDate",
    "ReturnDate",
    "DepositDate",
    "EarlyRPL",
    "LatestRPL",
    "InitialSystemDate",
    "FirstMeeting",
    "LastMeeting"
]

for col in date_cols:
    data[col] = pd.to_datetime(data[col], format="%m/%d/%y", errors="coerce")

# %%
data["days_to_departure"] = (data["DepartureDate"] - data["DepositDate"]).dt.days
data["planning_window"] = (data["DepartureDate"] - data["InitialSystemDate"]).dt.days
data["meeting_span"] = (data["LastMeeting"] - data["FirstMeeting"]).dt.days
data["deposit_to_first_meeting"] = (data["FirstMeeting"] - data["DepositDate"]).dt.days

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2389 entries, 0 to 2388
# Data columns (total 59 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ProgramCode                     2389 non-null   object
#  1   FromGrade                       2389 non-null   int64
#  2   ToGrade                         2389 non-null   int64
#  3   GroupState                      2389 non-null   object
#  4   IsNonAnnual                     2389 non-null   int64
#  5   Days                            2389 non-null   int64
#  6   TravelType                      2389 non-null   object
#  7   DepartureDate                   2389 non-null   datetime64[ns]
#  8   ReturnDate                      2389 non-null   datetime64[ns]
#  9   DepositDate                     2389 non-null   datetime64[ns]
#  10  SpecialPay                      2389 non-null   object
#  11  Tuition                         2389 non-null   int64
#  12  FRPActive                       2389 non-null   int64
#  13  FRPCancelled                    2389 non-null   int64
#  14  FRPTakeuppercent                2389 non-null   float64
#  15  EarlyRPL                        2389 non-null   datetime64[ns]
#  16  LatestRPL                       2389 non-null   datetime64[ns]
#  17  CancelledPax                    2389 non-null   int64
#  18  TotalDiscountPax                2389 non-null   int64
#  19  InitialSystemDate               2389 non-null   datetime64[ns]
#  20  PovertyCode                     2389 non-null   object
#  21  Region                          2389 non-null   object
#  22  CRMSegment                      2389 non-null   int64
#  23  SchoolType                      2389 non-null   object
#  24  ParentMeetingFlag               2389 non-null   int64
#  25  MDRLowGrade                     2389 non-null   object
#  26  MDRHighGrade                    2389 non-null   int64
#  27  TotalSchoolEnrollment           2389 non-null   int64
#  28  IncomeLevel                     2389 non-null   object
#  29  EZPayTakeUpRate                 2389 non-null   float64
#  30  SchoolSponsor                   2389 non-null   int64
#  31  SPRProductType                  2389 non-null   object
#  32  SPRNewExisting                  2389 non-null   object
#  33  FPP                             2389 non-null   int64
#  34  TotalPax                        2389 non-null   int64
#  35  SPRGroupRevenue                 2389 non-null   int64
#  36  NumberOfMeetingswithParents     2389 non-null   int64
#  37  FirstMeeting                    2389 non-null   datetime64[ns]
#  38  LastMeeting                     2389 non-null   datetime64[ns]
#  39  DifferenceTraveltoFirstMeeting  2389 non-null   int64
#  40  DifferenceTraveltoLastMeeting   2389 non-null   int64
#  41  SchoolGradeTypeLow              2389 non-null   object
#  42  SchoolGradeTypeHigh             2389 non-null   object
#  43  SchoolGradeType                 2389 non-null   object
#  44  DepartureMonth                  2389 non-null   object
#  45  GroupGradeTypeLow               2389 non-null   object
#  46  GroupGradeTypeHigh              2389 non-null   object
#  47  GroupGradeType                  2389 non-null   object
#  48  MajorProgramCode                2389 non-null   object
#  49  SingleGradeTripFlag             2389 non-null   int64
#  50  FPPtoSchoolenrollment           2389 non-null   float64
#  51  FPPtoPAX                        2389 non-null   float64
#  52  NumofNonFPPPAX                  2389 non-null   int64
#  53  SchoolSizeIndicator             2389 non-null   object
#  54  RetainedLabel                   2389 non-null   int64
#  55  days_to_departure               2389 non-null   int64
#  56  planning_window                 2389 non-null   int64
#  57  meeting_span                    2389 non-null   int64
#  58  deposit_to_first_meeting        2389 non-null   int64
# dtypes: datetime64[ns](8), float64(4), int64(27), object(20)
# memory usage: 1.1+ MB

# %%
import pandas as pd

# Filter for only integer and float columns
numeric_df = data.select_dtypes(include=['number'])

# Calculate the Pearson correlation matrix
corr_matrix = numeric_df.corr()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix of Numeric Features")
plt.show()

# %%
target_corr = numeric_df.corr()['RetainedLabel'].sort_values(ascending=False)


target_corr = target_corr.drop('RetainedLabel')

plt.figure(figsize=(10, 8))
target_corr.plot(kind='barh', color='skyblue')
plt.title("Correlations with RetainedLabel")
plt.xlabel("Correlation Coefficient")
plt.axvline(x=0, color='black', linestyle='-', linewidth=1)
plt.show()

# %% [markdown]
# ## K-Nearest Neighbors

# %% [markdown]
# ## Tree-Based Classification

# %% [markdown]
# ## New Method Classification
#
# Supervised Learning Documentation
#
# [See scikit-learn's Supervised Learning Documentation for more information about other classification methods](https://scikit-learn.org/stable/supervised_learning.html)

# %%
#libraries
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF, Matern, RationalQuadratic, ConstantKernel as C
from sklearn.datasets import make_moons
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import mutual_info_classif
from sklearn.feature_selection import RFECV
from sklearn.metrics import roc_auc_score
from sklearn.inspection import permutation_importance

# %% [markdown]
# Feature Selection - figure out which features to place in GPC model

# %%
# Make a copy of data
data_feature_section = data.copy()

# %% [markdown]
# Rank features by mututal importance

# %%
# Remove datetime columns
data_feature_section_mi = data_feature_section.select_dtypes(exclude=['datetime'])

# Create dummy variables for categorical variables
data_feature_section_mi = pd.get_dummies(data_feature_section_mi, drop_first=True)
# Define features (X) and target (y) of the whole dataset
X = data_feature_section_mi.drop("RetainedLabel", axis=1)
y = data_feature_section_mi["RetainedLabel"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-171/3214640640.py in <cell line: 0>()
#       1 # Remove datetime columns
# ----> 2 data_feature_section_mi = data_feature_section.select_dtypes(exclude=['datetime'])
#       3
#       4 # Create dummy variables for categorical variables
#       5 data_feature_section_mi = pd.get_dummies(data_feature_section_mi, drop_first=True)
#
# NameError: name 'data_feature_section' is not defined

# %%
# Filter features by mutual information
# MI measures the amount of shared information between two random variables
mi = mutual_info_classif(X, y)

# Combine scores with column names
mi_series = pd.Series(mi, index=X.columns)

# Sort features by importance (descending)
mi_series = mi_series.sort_values(ascending=False)

# View top 10 features
print(mi_series.head(10))
# Out:
# FromGrade              0.098527
# SingleGradeTripFlag    0.095841
# IsNonAnnual            0.069723
# SPRNewExisting_NEW     0.064977
# FPP                    0.061237
# TotalPax               0.052680
# EZPayTakeUpRate        0.043854
# FRPActive              0.043756
# NumofNonFPPPAX         0.041120
# FPPtoPAX               0.038429
# dtype: float64

# %% [markdown]
# I have create a list of features that I would like to explore visually:
# * days_to_departure
# * planning_window
# * meeting_span
# * IncomeLevel
# * TotalSchoolEnrollment
# * DepartureMonth
# * IsNonAnnual
# * Tuition
# * SingleGradeTripFlag
# * SPRNewExisting
# * FPP
# * FRPActive

# %%
#functions to create visiualization to compare the features against the RetainedLabel
#function to create boxplot
def boxplot_retention(feature, feature_label):

  sns.boxplot(x='RetainedLabel', y=feature, data=data_feature_section)
  plt.title(feature_label + ' by Retention Category')
  plt.show()

#function to create histogram
def histplot_retention(feature, feature_label):

  sns.histplot(data=data_feature_section, x=feature, hue='RetainedLabel', element='step', stat='density', common_norm=False)
  plt.title(feature_label + ' Distribution by Retention Category')
  plt.show()

def barplot_bin_retention(feature, feature_label, bins_num):

  # Bin days_to_departure
  data_feature_section['bins'] = pd.cut(data_feature_section[feature], bins=bins_num)

  # Compute retention rate per bin
  retention_rate = data_feature_section.groupby('bins')['RetainedLabel'].mean().reset_index()

  # Compute overall average retention
  overall_avg = data_feature_section['RetainedLabel'].mean()

  # Plot barplot
  sns.barplot(x='bins', y='RetainedLabel', data=retention_rate)
  plt.xticks(rotation=45)
  plt.ylabel('Retention Rate')
  plt.title('Retention Rate by ' + feature_label)

  # Add average line
  plt.axhline(overall_avg, color='red', linestyle='--', label=f'Overall Avg: {overall_avg:.2f}')
  plt.legend()

  plt.show()

def countplot_retention(feature, feature_label):

  sns.countplot(x=feature, hue='RetainedLabel', data=data_feature_section)
  plt.xticks(rotation=45)
  plt.ylabel('Count')
  plt.title('Retention by ' + feature_label)
  plt.show()

# %%
barplot_bin_retention('days_to_departure', 'Days to Departure', 10)

barplot_bin_retention('planning_window', 'Planning Window', 10)

boxplot_retention('meeting_span', 'Meeting Span')

countplot_retention('IncomeLevel', 'Income Level')

histplot_retention('TotalSchoolEnrollment', 'Total School Enrollment')

countplot_retention('DepartureMonth', 'Departure Month')

countplot_retention('IsNonAnnual', 'Is Non Annual')

barplot_bin_retention('Tuition', 'Tuition', 10)

countplot_retention('SingleGradeTripFlag', 'Single Grade Trip Flag')

countplot_retention('SPRNewExisting', 'SPR New Existing')

histplot_retention('FPP', 'FPP')
# Out:
# /tmp/ipython-input-186/2770065007.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retention_rate = data_feature_section.groupby('bins')['RetainedLabel'].mean().reset_index()
# /tmp/ipython-input-186/2770065007.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retention_rate = data_feature_section.groupby('bins')['RetainedLabel'].mean().reset_index()

# %%
barplot_bin_retention('planning_window', 'Planning Window', 10)
# Out:
# /tmp/ipython-input-186/2770065007.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retention_rate = data_feature_section.groupby('bins')['RetainedLabel'].mean().reset_index()

# %%
boxplot_retention('meeting_span', 'Meeting Span')

# %%
countplot_retention('IncomeLevel', 'Income Level')

# %%
histplot_retention('TotalSchoolEnrollment', 'Total School Enrollment')

# %%
countplot_retention('DepartureMonth', 'Departure Month')

# %%
countplot_retention('IsNonAnnual', 'Is Non Annual')

# %%
barplot_bin_retention('Tuition', 'Tuition', 10)
# Out:
# /tmp/ipython-input-186/2770065007.py:21: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   retention_rate = data_feature_section.groupby('bins')['RetainedLabel'].mean().reset_index()

# %%
countplot_retention('SingleGradeTripFlag', 'Single Grade Trip Flag')

# %%
countplot_retention('SPRNewExisting', 'SPR New Existing')

# %%
histplot_retention('FPP', 'FPP')

# %%
histplot_retention('FRPActive', 'FRP Active')

# %% [markdown]
# I chose to select the following columns:
# * planning_window
# * TotalSchoolEnrollment
# * DepartureMonth
# * IsNonAnnual
# * Tuition
# * SingleGradeTripFlag
# * SPRNewExisting
# * FPP

# %%
selected_columns = ["planning_window",
                    "TotalSchoolEnrollment",
                    "DepartureMonth",
                    "IsNonAnnual",
                    "Tuition",
                    "SingleGradeTripFlag",
                    "SPRNewExisting",
                    "FPP",

                    "RetainedLabel"]

data_columns = data[selected_columns]

# %%
data_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2389 entries, 0 to 2388
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   planning_window        2389 non-null   int64
#  1   TotalSchoolEnrollment  2389 non-null   int64
#  2   DepartureMonth         2389 non-null   object
#  3   IsNonAnnual            2389 non-null   int64
#  4   Tuition                2389 non-null   int64
#  5   SingleGradeTripFlag    2389 non-null   int64
#  6   SPRNewExisting         2389 non-null   object
#  7   FPP                    2389 non-null   int64
#  8   RetainedLabel          2389 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 168.1+ KB

# %%
# Convert categorical features to numerical using one-hot encoding
data_columns = pd.get_dummies(data_columns, drop_first=True)

# Define features (X) and target (y)
X = data_columns.drop("RetainedLabel", axis=1)
y = data_columns["RetainedLabel"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
#limit train size to 1000 so that the model runs faster during the debuging stage
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=1000, stratify=y, random_state=42)

# %%
#takes 11 minutes to run
param_grid = {
    "kernel": [
        1.0 * RBF(),
        1.0 * Matern(nu=1.5),
        1.0 * Matern(nu=5.5),
        1.0 * RationalQuadratic()
    ],
    "n_restarts_optimizer": [0, 5]
}

gpc = GaussianProcessClassifier(random_state=42)

grid = GridSearchCV(
    gpc,
    param_grid,
    cv=5,
    n_jobs=-1
)

grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'kernel': 1**2 * Matern(length_scale=1, nu=1.5), 'n_restarts_optimizer': 0}
# 0.7700000000000001

# %%
# Define the Gaussian Process kernel
# Kernel = Constant * RBF
kernel = C(1.0) * Matern(length_scale=1, nu=1.5)

# Initialize the Gaussian Process Classifier
gpc = GaussianProcessClassifier(kernel=kernel, random_state=42, n_restarts_optimizer=0)

# Fit the model
gpc.fit(X_train, y_train)

# Make predictions
gpc_y_pred = gpc.predict(X_test)

# Evaluate the model
print("GPC Accuracy:", accuracy_score(y_test, gpc_y_pred))
print("\nGPC Classification Report:\n", classification_report(y_test, gpc_y_pred))

cm = confusion_matrix(y_test, gpc_y_pred)

# Create the confusion matrix display
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Retained', 'Churned'])

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('GPC Confusion Matrix')
plt.show()
# Out:
# GPC Accuracy: 0.8120950323974082
#
# GPC Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85       844
#            1       0.80      0.70      0.74       545
#
#     accuracy                           0.81      1389
#    macro avg       0.81      0.79      0.80      1389
# weighted avg       0.81      0.81      0.81      1389

# %%
# Split the data into training and testing sets
#use test_size = 0.2 to fit the model on more of the training data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Define the Gaussian Process kernel
# Kernel = Constant * RBF
kernel = C(1.0) * Matern(length_scale=1, nu=1.5)

# Initialize the Gaussian Process Classifier
gpc = GaussianProcessClassifier(kernel=kernel, random_state=42, n_restarts_optimizer=0)

# Fit the model
gpc.fit(X_train, y_train)

# Make predictions
gpc_y_pred = gpc.predict(X_test)

# Evaluate the model
print("GPC Accuracy:", accuracy_score(y_test, gpc_y_pred))
print("\nGPC Classification Report:\n", classification_report(y_test, gpc_y_pred))

cm = confusion_matrix(y_test, gpc_y_pred)

# Create the confusion matrix display
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Retained', 'Churned'])

# Plot the confusion matrix
disp.plot(cmap='Blues')
plt.title('GPC Confusion Matrix')
plt.show()
# Out:
# GPC Accuracy: 0.8326359832635983
#
# GPC Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87       290
#            1       0.81      0.75      0.78       188
#
#     accuracy                           0.83       478
#    macro avg       0.83      0.82      0.82       478
# weighted avg       0.83      0.83      0.83       478

# %%
y_prob = gpc.predict_proba(X_test)[:, 1]

auc = roc_auc_score(y_test, y_prob)
print("ROC AUC:", auc)
# Out:
# ROC AUC: 0.8879677182685253

# %%
# Variable Importance Plot
# Based of permutation importance: shuffle one feature at a time and measure how much model performance drops
# Score based off ROC AUC
result = permutation_importance(
    gpc,
    X_test,
    y_test,
    scoring="roc_auc",
    n_repeats=10,
    random_state=42
)


importances = pd.Series(result.importances_mean, index=X.columns)
importances = importances.sort_values(ascending=False)

# %%
importances.plot(kind='barh')
plt.xlabel("Mean Decrease in AUC")
plt.title("Permutation Importance - Gaussian Process")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ## Make Predictions on Unknown Data

# %%
# Create the final model using all of the data
# Kernel = Constant * RBF
kernel = C(1.0) * Matern(length_scale=1, nu=1.5)

# Initialize the Gaussian Process Classifier
gpc = GaussianProcessClassifier(kernel=kernel, random_state=42, n_restarts_optimizer=0)

# Fit the model
gpc.fit(X_scaled, y)
# Out:
# GaussianProcessClassifier(kernel=1**2 * Matern(length_scale=1, nu=1.5),
#                           random_state=42)

# %%
prediction_data = pd.read_csv('https://www.dropbox.com/scl/fi/hveyqinjaurpm2e1s5uh2/scholastic_travel_predictions.csv?rlkey=3sx0cjmaubjafwripmcsfhktd&st=lbb9ii3b&dl=1')

prediction_data.head()
# Out:
#   ProgramCode  FromGrade  ToGrade GroupState  IsNonAnnual  Days TravelType  \
# 0          HD          8        8         FL            0     3          A
# 1       Other          9        9      Other            0     8          A
# 2       Other          8        8         AZ            0     8          A
# 3          HD          8        8         TX            0     4          A
# 4          HD          5        5         CA            0     6          A
#
#   DepartureDate ReturnDate DepositDate  ... GroupGradeTypeLow  \
# 0       1/15/11    1/17/11    10/15/10  ...            Middle
# 1       1/24/11    1/31/11     10/1/10  ...         Undefined
# 2       1/29/11     2/5/11      6/1/10  ...            Middle
# 3        2/7/11    2/10/11    10/25/10  ...                PK
# 4       2/13/11    2/18/11    10/15/10  ...         Undefined
#
#    GroupGradeTypeHigh        GroupGradeType  MajorProgramCode  \
# 0              Middle        Middle->Middle                 H
# 1           Undefined  Undefined->Undefined             Other
# 2                High          Middle->High                 C
# 3              Middle            PK->Middle                 H
# 4           Undefined  Undefined->Undefined                 H
#
#    SingleGradeTripFlag FPPtoSchoolenrollment  FPPtoPAX  NumofNonFPPPAX  \
# 0                    1              0.025131  0.888889               3
# 1                    1              0.000000  0.928571               1
# 2                    1              0.104000  0.928571               4
# 3                    1              0.103937  0.916667               6
# 4                    1              0.000000  0.891892               4
#
#    SchoolSizeIndicator RetainedLabel
# 0                    L           NaN
# 1             FIXED_NA           NaN
# 2                  S-M           NaN
# 3                  M-L           NaN
# 4             FIXED_NA           NaN
#
# [5 rows x 55 columns]

# %%
for col in date_cols:
    prediction_data[col] = pd.to_datetime(prediction_data[col], format="%m/%d/%y", errors="coerce")

# %%
prediction_data["days_to_departure"] = (prediction_data["DepartureDate"] - prediction_data["DepositDate"]).dt.days
prediction_data["planning_window"] = (prediction_data["DepartureDate"] - prediction_data["InitialSystemDate"]).dt.days
prediction_data["meeting_span"] = (prediction_data["LastMeeting"] - prediction_data["FirstMeeting"]).dt.days
prediction_data["deposit_to_first_meeting"] = (prediction_data["FirstMeeting"] - prediction_data["DepositDate"]).dt.days

# %%
prediction_data = prediction_data[selected_columns]

prediction_data = pd.get_dummies(prediction_data, drop_first=True)

X_pred = prediction_data.drop('RetainedLabel', axis=1)

# make sure we have the same columns in this dataset as in training
training_features = X.columns
X_pred = X_pred.reindex(columns=training_features, fill_value=0)

scaler = StandardScaler()
X_pred = scaler.fit_transform(X_pred)

# %%
# Add the predictions to the prediction_data DataFrame
prediction_data['RetainedLabel'] = gpc.predict(X_pred)
mapping = {0: 'Retained', 1: 'Churned'}
data['RetainedLabel'] = data['RetainedLabel'].map(mapping)

# %%
# Save files

prediction_data.to_csv('Classification Project Predictions.csv', index=False)
files.download('Classification Project Predictions.csv')
